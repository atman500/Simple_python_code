# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('macro.csv')
print(df.head())
# Out:
#           GDP  Investment
# 0  308.572288  109.934283
# 1  285.394462   97.234714
# 2  333.720595  112.953771
# 3  379.347632  130.460597
# 4  283.531512   95.316933

# %%
gdp=df['GDP']
inv=df['Investment']

# %%
print(gdp.head())
print(inv.head())
# Out:
# 0    308.572288
# 1    285.394462
# 2    333.720595
# 3    379.347632
# 4    283.531512
# Name: GDP, dtype: float64
# 0    109.934283
# 1     97.234714
# 2    112.953771
# 3    130.460597
# 4     95.316933
# Name: Investment, dtype: float64
